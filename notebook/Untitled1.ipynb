# %%
#Name model

import os
import sys
from pathlib import Path
import numpy as np
import flopy
import SGD
import config
import datetime
import simulationFFT
import utils

modelname = 'test'

###### INPUT ########
# it = sys.argv[1]
# MC_file = Path(sys.argv[2])
# basecase_ws = Path(sys.argv[3])
# swexe = '/home/groups/rknight/swtv4'
it = 0
MC_file = Path('../work/heterog_1000/MC_expt_20200202_1427/expt.txt')
basecase_ws =  Path('../work/homog/')
fpath_basecase = basecase_ws.joinpath(basecase_ws.parts[-1] + '.nam').as_posix()
swexe = config.swexe

print(os.getcwd())
print('Running iteration {} \n'
	'MC_file: {} \n'
	'basecase workspace: {} \n'.format(it,MC_file,basecase_ws))
#####################

# repo = Path('/scratch/users/ianpg/henry')
repo = Path('/Users/ianpg/Documents/ProjectsLocal/SWIsmall')

workdir = repo.joinpath('work')
figdir = workdir.joinpath('figs')
datadir = repo.joinpath('data')
objdir = repo.joinpath('data', 'objs')
model_ws = repo.joinpath('work', modelname)    
for p in (workdir,figdir,datadir,objdir,model_ws):
    if not p.exists():
        p.mkdir()

#Load model
m = flopy.seawat.Seawat.load(fpath_basecase)
SGD.ModelSGD.Seawat2SGD(m)  #convert to subclass ModelSGD
m.MC_file = MC_file
model_ws = MC_file.parent.joinpath('tmp{}'.format(it))
if not model_ws.exists():
    model_ws.mkdir()
m.model_ws = model_ws.as_posix()
m.name = modelname


m.exe_name = swexe
nrow,ncol,nlay,nper = m.nrow_ncol_nlay_nper
henry_top,henry_botm = m.dis.top, m.dis.botm
delr,delc = m.dis.delr.array[0], m.dis.delc.array[0]

Lx = 3000.
Ly = 600.
Lz = 80.

henry_top = 3
ocean_elev = 0
delv_first = 5


botm_first = henry_top - delv_first

nlay = int(Lz * 1 / 3)
nrow = int(Ly * (1 / 30))
ncol = int(Lx * (1 / 30))

delv = (Lz - delv_first) / (nlay - 1)
delr = Lx / ncol
delc = Ly / nrow

henry_botm = np.hstack(([botm_first], np.linspace(
    botm_first - delv, henry_top - Lz, nlay - 1)))
delv_vec = np.hstack((delv_first, np.repeat(delv, nlay - 1)))
delv_weight = [x / np.sum(delv_vec) for x in delv_vec]


# Period data
nyrs = 20
Lt = 360 * nyrs  # Length of time in days
perlen = list(np.repeat(180, int(Lt / 180)))
nstp = list(np.ones(np.shape(perlen), dtype=int))

nper = len(perlen)
steady = [False for x in range(len(perlen))]  # Never steady
itmuni = 4  # time unit 4= days
lenuni = 2  # length unit 2 = meter
tsmult = 1.8
ssm_data = None
verbose = False
kper_odd = list(np.arange(1, nper, 2))
kper_even = list(np.arange(0, nper, 2))


# Variable density parameters
Csalt = 35.0001
Cfresh = 0.
densesalt = 1025.
densefresh = 1000.
denseslp = (densesalt - densefresh) / (Csalt - Cfresh)

#Load varlist
varlist = utils.load_obj(m.MC_file.parent,'varlist')
right_edge = utils.load_obj(basecase_ws, 'right_edge')
farm_loc_list = utils.load_obj(basecase_ws,'farm_loc_list')
farm_orig = [(1, 50), (9, 50), (1, 58), (9, 58)]
n_wells = len(farm_orig)
wel_cells = utils.load_obj(basecase_ws,'wel_cells')
riv_loc = utils.load_obj(basecase_ws,'riv_loc')

# sys.path.append(repo.joinpath('notebook').as_posix())
sw_exe = config.swexe  # set the exe path for seawat
print('Model workspace:', model_ws)

def normal_transform(data1,mu1,mu2,sig1,sig2):
    a = sig2/sig1
    b = mu2 - mu1 * a
    return a*data1 + b

def record_salinity(m,totim=None,writeyn=True,fname_write=None,ts_hms=None):
    if ts_hms is None:
        ts_hms = datetime.datetime.now().strftime('%H-%M-%S')
    # Extract final timestep salinity
    fname = os.path.join(m.model_ws, 'MT3D001.UCN')
    ucnobj = flopy.utils.binaryfile.UcnFile(fname)
    if totim is None:
        totim = ucnobj.get_times()[-1]
    conc = ucnobj.get_data(totim=totim)
    if writeyn:
        if fname_write is None:
            fname_write = m.MC_file.parent.joinpath('conc_' + str(int(totim)) + '_' + ts_hms + '.npy')
        print(fname_write)
        np.save(fname_write,conc)
    return conc

def get_hds(m,kstpkper=None):
    f_hds = Path(m.name + '.hds')
    hdsobj = flopy.utils.binaryfile.HeadFile(f_hds.as_posix())
    if kstpkper is None:
        kstpkper = hdsobj.get_kstpkper()[-1]
    return hdsobj.get_data(kstpkper=kstpkper)

def get_base_hds_conc(ws):
    f_ucn = ws.joinpath('MT3D001.UCN')
    ucnobj = flopy.utils.binaryfile.UcnFile(f_ucn.as_posix())
    kstpkperu = ucnobj.get_kstpkper()[-1]

    f_hds = ws.joinpath(ws.parts[-1] + '.hds')
    hdsobj = flopy.utils.binaryfile.HeadFile(f_hds.as_posix())
    kstpkperh = hdsobj.get_kstpkper()[-1]
    return hdsobj.get_data(kstpkper=kstpkperh), ucnobj.get_data(kstpkper=kstpkperu), 

def get_ocean_right_edge(m, ocean_line_tuple, startlay=None, col=None):
    import numpy as np
    point_list = []

    if col is None:
        col = m.ncol - 1
    # If there is no vertical side boundary, return bottom-right corner node
    if len(ocean_line_tuple) == 0:
        if startlay is None:
            startlay = 0
    elif max(ocean_line_tuple[0]) == m.nlay:
        startlay = m.nlay
    elif max(ocean_line_tuple[0]) < m.nlay:
        startlay = max(ocean_line_tuple[0])
    for lay in range(startlay, m.nlay):
        for row in range(m.nrow):
            point_list.append((lay, row, col))
    point_list = tuple(np.array(point_list).T)
    return point_list

def find_nearest(array, value):
    import numpy as np
    idx = (np.abs(array - value)).argmin()
    idx.astype('int')
    return array[idx]

def make_bc_dicts(head_inland_sum_wint):
    #Ocean and inland boundary types
    bc_right_edge='GHB'
    bc_inland = 'GHB'
    ocean_elev =0
    hkSand = 100

    itype = flopy.mt3d.Mt3dSsm.itype_dict()
    chd_data = {}
    ssm_data = {}
    ghb_data = {}
    wel_data = {}
    for i in range(nper):
        dat_chd = []
        dat_ssm = []
        dat_ghb = []
        dat_wel = []
        #Ocean boundary
        # if ocean_hf:
        #     for j in range(np.size(ocean_hf[0])):
        #         if bc_ocean=='CHD':
        #             #CHD: {stress_period: [lay,row,col,starthead,endhead]}
        #             dat_chd.append([ocean_line_tuple[0][j],
        #                         ocean_line_tuple[1][j],
        #                         ocean_line_tuple[2][j],
        #                         ocean_shead[i],
        #                         ocean_ehead[i]])
        #             #SSM: {stress_period: [lay,row,col,concentration,itype]}
        #             dat_ssm.append([ocean_line_tuple[0][j],
        #                         ocean_line_tuple[1][j],
        #                         ocean_line_tuple[2][j],
        #                         Csalt,
        #                         itype['CHD']])
        #         elif bc_ocean=='GHB':
        #             #GHB: {stress period: [lay,row,col,head level,conductance]}
        #             #conductance c = K*A/dL; assume horizontal flow at outlet,
        #             #and calculate length to be at edge of ocean cell, as opposed to mipoint
        #             # c = (K*dy*dz)/(dx/2) = 2*K*delr*delv/delc
        #             dat_ghb.append([ocean_hf[0][j],
        #                            ocean_hf[1][j],
        #                            ocean_hf[2][j],
        #                            #ocean_hf[3][j],
        #                             ocean_elev,
        #                            2*hkSand*delc*delv_vec[ocean_hf[0][j]]/delr])
        #             #SSM: {stress_period: [lay,row,col,concentration,itype]}
        #             dat_ssm.append([ocean_hf[0][j],
        #                            ocean_hf[1][j],
        #                            ocean_hf[2][j],
        #                            Csalt,
        #                            itype['GHB']])
        if False:
        	pass
        else:
            pass
        #Right edge boundary
        if bc_right_edge=='GHB':
            for j in range(np.size(right_edge[0])):
                #GHB: {stress period: [lay,row,col,head level,conductance]}
                #conductance c = K*A/dL; assume horizontal flow at outlet,
                #and calculate length to be at edge of ocean cell, as opposed to mipoint
                # c = (K*dy*dz)/(dx/2) = 2*K*delr*delv/delc
                dat_ghb.append([right_edge[0][j],
                               right_edge[1][j],
                               right_edge[2][j],
                               #ocean_hf[3][j],
                                ocean_elev,
                               2*hkSand*delc*delv_vec[right_edge[0][j]]/delr])
                #SSM: {stress_period: [lay,row,col,concentration,itype]}
                dat_ssm.append([right_edge[0][j],
                               right_edge[1][j],
                               right_edge[2][j],
                               Csalt,
                               itype['GHB']])
        else:
            pass
        #Inland boundary
        if bc_inland=='GHB':
            if i in kper_odd:
                head_inland = head_inland_sum_wint[0]
            elif i in kper_even:
                head_inland = head_inland_sum_wint[1]
            left_edge = get_ocean_right_edge(m,tuple([]),
                  int(np.where(henry_botm==find_nearest(henry_botm,head_inland))[0]),
                col=0)
            for j in range(np.size(left_edge[0])):
                dat_ghb.append([left_edge[0][j],
                               left_edge[1][j],
                               left_edge[2][j],
                                head_inland,
                               2*hkSand*delc*delv_vec[left_edge[0][j]]/delr])
                #SSM: {stress_period: [lay,row,col,concentration,itype]}
                dat_ssm.append([left_edge[0][j],
                               left_edge[1][j],
                               left_edge[2][j],
                               Cfresh,
                               itype['GHB']])
        chd_data[i] = dat_chd
        ssm_data[i] = dat_ssm
        ghb_data[i] = dat_ghb
        wel_data[i] = dat_wel

    #saving concentrations at specified times
    #timprs = [k for k in range(1,np.sum(perlen),50)]
    return chd_data, ssm_data, ghb_data, wel_data

def add_pumping_wells(wel_data,ssm_data,n_wells,flx,rowcol,kper):
    itype = flopy.mt3d.Mt3dSsm.itype_dict()
    new_weldata = wel_data
    new_ssmdata = ssm_data
    wel_cells = []
    for k in range(n_wells):
        row,col = rowcol[k]
        for i in range(nper):
            if i in kper:
                for j in range(nlay):
                    #WEL {stress_period: [lay,row,col,flux]}
                    new_weldata[i].append([j,row,col,-flx[k]*delv_weight[j]])
                    wel_cells.append((j,row,col))
                    #SSM: {stress_period: [lay,row,col,concentration,itype]}
                    new_ssmdata[i].append([j,row,col,Cfresh,itype['WEL']]) #since it's a sink, conc. doesn't matter
            else:
                for j in range(nlay):
                    #WEL {stress_period: [lay,row,col,flux]}
                    new_weldata[i].append([j,row,col,0])
                    #SSM: {stress_period: [lay,row,col,concentration,itype]}
                    new_ssmdata[i].append([j,row,col,Cfresh,itype['WEL']]) #since it's a sink, conc. doesn't matter
                    wel_cells.append((j,row,col))
                continue
    wel_cells = tuple(np.array(list(set(wel_cells))).T)
    return new_weldata, new_ssmdata,wel_cells

def write_river_data(riv_loc, stage, cond, riv_grad, kper, ssm_data):

    ####ADD RIVER DATA####
    rbot_vec = np.linspace(riv_grad * Lx, ocean_elev, ncol)

    itype = flopy.mt3d.Mt3dSsm.itype_dict()
    riv_data = {}
    new_ssm_data = ssm_data
    for i in range(nper):
        dat_riv = []
        if i in kper:
            for j in range(np.size(riv_loc[0])):
                # RIV: {stress_period:[lay, row, col, stage, cond, rbot],...}
                dat_riv.append([riv_loc[0][j],
                                riv_loc[1][j],
                                riv_loc[2][j],
                                stage + rbot_vec[riv_loc[2][j]],
                                cond,
                                rbot_vec[riv_loc[2][j]]])
                # SSM: {stress_period: [lay,row,col,concentration,itype]}
                new_ssm_data[i].append([riv_loc[0][j],
                                        riv_loc[1][j],
                                        riv_loc[2][j],
                                        Cfresh,
                                        itype['RIV']])
        else:
            for j in range(np.size(riv_loc[0])):
                # RIV: {stress_period:[lay, row, col, stage, cond, rbot],...}
                dat_riv.append([riv_loc[0][j],
                                riv_loc[1][j],
                                riv_loc[2][j],
                                # set stage as bottom of river
                                rbot_vec[riv_loc[2][j]],
                                cond,
                                rbot_vec[riv_loc[2][j]]])
                # SSM: {stress_period: [lay,row,col,concentration,itype]}
                new_ssm_data[i].append([riv_loc[0][j],
                                        riv_loc[1][j],
                                        riv_loc[2][j],
                                        Cfresh,
                                        itype['RIV']])
        riv_data[i] = dat_riv
    return riv_data, new_ssm_data


def update_run_model(varlist, it, m=m, homogenous=2, runyn=True,
                     plotyn=False,silent=True,start_basecase=True,
                     f_basecase=None,pooling=True,output=None,results=[]):
    # Make timestamp
    ts = utils.make_timestamp()
    print('Running it {} at time {}'.format(it,ts))
    
    if start_basecase:
        strt,sconc = get_base_hds_conc(basecase_ws)
    
    if pooling:
        model_ws_orig = Path(m.model_ws).as_posix() + ''
        tmp = Path(model_ws).joinpath('tmp{}'.format(it))
        if not tmp.exists():
            tmp.mkdir()
        m.model_ws = tmp.as_posix()
        print('temp ws', m.model_ws)

    # unpack values from varlist
    vka = varlist['vka'][it]
    al = varlist['al'][it]
    dmcoef = varlist['dmcoef'][it]
    ss = varlist['ss'][it]
    sy = varlist['sy'][it]

    riv_stg = varlist['riv_stg'][it]
    riv_cond = varlist['riv_cond'][it]
    head_inland_sum = varlist['head_inland_sum'][it]
    head_inland_wint = varlist['head_inland_wint'][it]
    wel = varlist['wel'][:,it]
    rech_farm_pct = varlist['rech_farm'][0]
    farm_size = (200,200)
    rech_farm = [rech_farm_pct*flx/np.prod(farm_size) for flx in wel]
    rech_precip = varlist['rech'][it]
    
    CF_glob = varlist['CF_glob'][it]
    CF_var = varlist['CF_var'][it]
    seed = varlist['seed'][it]
    hk_mean = varlist['hk_mean'][it]
    hk_var = varlist['hk_var'][it]
    por_mean = varlist['por_mean'][it]
    por_var = varlist['por_var'][it]
    corr_len = varlist['corr_len'][it]
    corr_len_yx = varlist['corr_len_yx'][it]
    corr_len_zx = varlist['corr_len_zx'][it]
    clay_lyr_yn = varlist['clay_lyr_yn'][it]
    vario_type = varlist['vario_type'][it]
    


    #set ghb data and create dicts
    chd_data, ssm_data_base, ghb_data, wel_data_base = make_bc_dicts((head_inland_sum,head_inland_wint))
    utils.save_obj(m.MC_file.parent,wel_data_base,'wel_data_base')
    utils.save_obj(m.MC_file.parent,ssm_data_base,'ssm_data_base')

    ssm_data = {}
    # write recharge data
    
    rech_farm_mat = np.zeros((nrow,ncol),dtype=np.float32)
    for i in range(len(rech_farm)):
        rech_farm_mat[farm_loc_list[i]] = rech_farm[i]
    
    rech_data = {}
    for i in range(len(perlen)):
        if i in kper_even:
            rech_data[i] = rech_precip
        elif i in kper_odd:
            rech_data[i] = rech_farm_mat


    # write wel data
    # ssm_data_base = load_obj(m.MC_file.parent, 'ssm_data_base')
    # wel_data_base = load_obj(m.MC_file.parent, 'wel_data_base')
    wel_data, ssm_data, wel_cells = add_pumping_wells(wel_data_base,
                                                      ssm_data_base,
                                                      n_wells,flx=wel,
                                                      rowcol=farm_orig,
                                                      kper=kper_odd)
    if homogenous==1:
        CF_grid = 1
        hk_grid = 10**hk_mean
        por_grid = .4
    elif homogenous==2:
        #Create Gaussian Simulation
        lcol = int(corr_len/delr)
        llay = int(corr_len*corr_len_zx/np.mean(delv))
        lrow = int(corr_len*corr_len_yx/delc)
    #     fft_grid = np.exp(simulationFFT.simulFFT(nrow, nlay, ncol, mu, sill, vario_type, lrow , llay, lcol))   
        CF_grid = simulationFFT.simulFFT(nrow,nlay, ncol,CF_glob,CF_var,vario_type, lrow , llay, lcol,seed=seed)
        hk_grid = 10**normal_transform(CF_grid,CF_glob,hk_mean,np.sqrt(CF_var),np.sqrt(hk_var))
        por_grid = normal_transform(CF_grid,CF_glob,por_mean,np.sqrt(CF_var),np.sqrt(por_var))
        CF_grid[CF_grid > 1.] = 1.
        CF_grid[CF_grid < 0.] = 0.
        por_grid[por_grid > 1.] = .99
        por_grid[por_grid < 0.] = 0.01    
        hk_grid[wel_cells] = np.max((hk_grid.max(),200))
        np.save(m.MC_file.parent.joinpath('{}_hk.npy'.format(ts)),hk_grid)
    else:
        pass


    # Write river data--take SSM data from WEL!!
    riv_grad = .0005
    riv_data, ssm_data = write_river_data(
        riv_loc, riv_stg, riv_cond, riv_grad, kper_even, ssm_data)
    ipakcb = 53
    icbund = np.ones((nlay, nrow, ncol), dtype=np.int)
    icbund[np.where(m.bas6.ibound.array == -1)] = -1
    timprs = np.round(np.linspace(1, np.sum(perlen), 20), decimals=0)
    oc_data = {}
    for kper in range(nper):
    	if kper % 5==0:
    		oc_data[(kper, 0)] = ['save head', 'save budget']

    bas = flopy.modflow.ModflowBas(m, m.bas6.ibound.array, strt=strt)
    ghb = flopy.modflow.ModflowGhb(m, stress_period_data=ghb_data)
    flopy.modflow.ModflowWel(m, stress_period_data=wel_data, ipakcb=ipakcb)
    flopy.modflow.ModflowRch(m, rech=rech_data)
    flopy.modflow.ModflowRiv(m, stress_period_data=riv_data)
	# Add LPF package to the MODFLOW model
    flopy.modflow.ModflowLpf(m, hk=hk_grid, vka=vka, ipakcb=ipakcb, laytyp=1,laywet=1,ss=ss,sy=sy)
	# Add PCG Package to the MODFLOW model
    flopy.modflow.ModflowPcg(m, hclose=1.e-8)
	# Add OC package to the MODFLOW model
    flopy.modflow.ModflowOc(m,stress_period_data=oc_data,compact=True)
    # Create the basic MT3DMS model structure
    flopy.mt3d.Mt3dBtn(m,
					laycon=m.lpf.laytyp, htop=henry_top,
					dz=m.dis.thickness.get_value(), prsity=por_grid, icbund=icbund,
					sconc=sconc, nprs=1, timprs=timprs)
    flopy.mt3d.Mt3dAdv(m, mixelm=-1)
    flopy.mt3d.Mt3dDsp(m, al=al, dmcoef=dmcoef)
    flopy.mt3d.Mt3dGcg(m, iter1=50, mxiter=1, isolve=1, cclose=1e-5)
    flopy.mt3d.Mt3dSsm(m, stress_period_data=ssm_data)

    #vdf = flopy.seawat.SeawatVdf(m, iwtable=0, densemin=0, densemax=0,denseref=1000., denseslp=0.7143, firstdt=1e-3)
    flopy.seawat.SeawatVdf(m, mtdnconc=1, mfnadvfd=1, nswtcpl=0, iwtable=1,
                                 densemin=0., densemax=0., denseslp=denseslp, denseref=densefresh)

    # Write input
    m.write_input()

    # Try to delete the output files, to prevent accidental use of older files
    flist = [os.path.join(model_ws, 'MT3D.CNF'),
             os.path.join(model_ws, 'MT3D001.MAS'),
             os.path.join(model_ws, modelname + '.hds'),
             os.path.join(model_ws, 'MT3D001.UCN'),
             os.path.join(model_ws, 'MT3D001.UCN'),
             os.path.join(model_ws, modelname + '.cbc')]
    for f in flist:
        try:
            os.remove(f)
        except:
            pass

    # Plot model? 
    if plotyn:
        m.plot_hk_ibound(rowslice=farm_orig[0][0],gridon=True)
        
    # Run model
    if runyn:
        v = m.run_model(silent=silent, report=True)
        for idx in range(-3, 0):  # Report
            print(v[1][idx])

        # Record success/failure and store data
        varlist['success'][it] = v[0]

        if v[0] is False:
            pass
        else:
            # Record final salinity as .npy, also move full CBC and UCN files
            # to expt folder
            fname = os.path.join(m.model_ws, 'MT3D001.UCN')
            totim = flopy.utils.binaryfile.UcnFile(fname).get_times()[-1]
            conc_fname = 'conc{}_{}_totim{}.UCN'.format(
                it, ts, str(int(totim)))
            _ = record_salinity(
                m, ts_hms=ts, fname_write=m.MC_file.parent.joinpath(conc_fname))
            copy_rename(os.path.join(m.model_ws, 'MT3D001.UCN'),
                        m.MC_file.parent.joinpath(conc_fname).as_posix())
    if pooling:
        try:
            # [print(p) for p in tmp.iterdir() if (p.suffix is not '.UCN')]
            [p.unlink() for p in tmp.iterdir() if (p.suffix not in ('.UCN','.list'))]
            # shutil.rmtree(tmp.as_posix())
            # tmp.rmdir()
        except:
            print('didnt work!')
            pass
        m.model_ws = model_ws_orig
        print('resetting ws:',m.model_ws)

        if output is None:
            return (it,varlist['success'][it])
        else:
            output.put((it,varlist['success'][it]))
            # results.append((it,varlist['success'][it]))
            return
    else:
        return m, varlist


def make_varlist_array(varlist,nwel=4):
    flag=0
    i=0
    for k,v in varlist.items():
        if flag==0:
            varlist_arr= np.zeros((len(varlist)+nwel,len(v)),dtype=np.float)
            flag=1
        if k is 'wel':
            for j in range(nwel):
                varlist_arr[i,:] = v[j,:]
                i+=1
        elif k is 'vario_type':
            varlist_arr[i,:] = [0 if model is 'Gaussian' else 1 for model in v]
            i+=1
        else:
            varlist_arr[i,:] = np.asarray(v,dtype=np.float)
            i+=1
    return varlist_arr
#%
# Out:
# /Users/ianpg/Documents/ProjectsLocal/SWIsmall/notebook
# Running iteration 0
# MC_file: ../work/heterog_1000/MC_expt_20200202_1427/expt.txt
# basecase workspace: ../work/homog
#
#
# changing model workspace...
#    ../work/heterog_1000/MC_expt_20200202_1427/tmp0
#
# changing model workspace...
#    ../work/heterog_1000/MC_expt_20200202_1427/tmp0
#
# changing model workspace...
#    ../work/heterog_1000/MC_expt_20200202_1427/tmp0
# Model workspace: ../work/heterog_1000/MC_expt_20200202_1427/tmp0

# %%
# Out:
# PosixPath('../work/heterog_1000/MC_expt_20200202_1427/tmp0')

# %%
runyn=True
pooling=False
# output = mp.Queue()

m, varlist = update_run_model(varlist,it,runyn=runyn,
                             start_basecase=True,silent=False,
                             pooling=pooling,f_basecase=fpath_basecase)

# varlist_arr = make_varlist_array(varlist)
# savemat(m.MC_file.parent.joinpath('inputParams.mat').as_posix(),varlist)
# np.save(m.MC_file.parent.joinpath('inputParams_all.npy'),varlist_arr)
# save_obj(m.MC_file.parent,varlist,'varlist_final')
# save_obj(m.MC_file.parent,m.dis.get_node_coordinates(),'yxz')
# Out:
# Running it 0 at time 20200202_1806
# WARNING: unit 13 of package BAS6 already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfbas.ModflowBas'> <class 'flopy.modflow.mfbas.ModflowBas'>
# replacing existing Package...
# WARNING: unit 23 of package GHB already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfghb.ModflowGhb'> <class 'flopy.modflow.mfghb.ModflowGhb'>
# replacing existing Package...
# WARNING: unit 20 of package WEL already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfwel.ModflowWel'> <class 'flopy.modflow.mfwel.ModflowWel'>
# replacing existing Package...
# WARNING: unit 19 of package RCH already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfrch.ModflowRch'> <class 'flopy.modflow.mfrch.ModflowRch'>
# replacing existing Package...
# WARNING: unit 18 of package RIV already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfriv.ModflowRiv'> <class 'flopy.modflow.mfriv.ModflowRiv'>
# replacing existing Package...
# WARNING: unit 15 of package LPF already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mflpf.ModflowLpf'> <class 'flopy.modflow.mflpf.ModflowLpf'>
# replacing existing Package...
# WARNING: unit 27 of package PCG already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfpcg.ModflowPcg'> <class 'flopy.modflow.mfpcg.ModflowPcg'>
# replacing existing Package...
# WARNING: unit 14 of package OC already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfoc.ModflowOc'> <class 'flopy.modflow.mfoc.ModflowOc'>
# replacing existing Package...
# WARNING: unit 31 of package BTN already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtbtn.Mt3dBtn'> <class 'flopy.mt3d.mtbtn.Mt3dBtn'>
# replacing existing Package...
# WARNING: unit 32 of package ADV already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtadv.Mt3dAdv'> <class 'flopy.mt3d.mtadv.Mt3dAdv'>
# replacing existing Package...
# WARNING: unit 33 of package DSP already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtdsp.Mt3dDsp'> <class 'flopy.mt3d.mtdsp.Mt3dDsp'>
# replacing existing Package...
# WARNING: unit 35 of package GCG already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtgcg.Mt3dGcg'> <class 'flopy.mt3d.mtgcg.Mt3dGcg'>
# replacing existing Package...
# found 'rch' in modflow model, resetting crch to 0.0
# WARNING: unit 34 of package SSM already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtssm.Mt3dSsm'> <class 'flopy.mt3d.mtssm.Mt3dSsm'>
# replacing existing Package...
# WARNING: unit 37 of package VDF already in use
# ****Warning -- two packages of the same type:  <class 'flopy.seawat.swtvdf.SeawatVdf'> <class 'flopy.seawat.swtvdf.SeawatVdf'>
# replacing existing Package...
# Util2d rech_2: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_1.ref
# Util2d rech_4: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_3.ref
# Util2d rech_6: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_5.ref
# Util2d rech_8: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_7.ref
# Util2d rech_10: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_9.ref
# Util2d rech_12: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_11.ref
# Util2d rech_14: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_13.ref
# Util2d rech_16: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_15.ref
# Util2d rech_18: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_17.ref
# Util2d rech_20: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_19.ref
# Util2d rech_22: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_21.ref
# Util2d rech_24: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_23.ref
# Util2d rech_26: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_25.ref
# Util2d rech_28: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_27.ref
# Util2d rech_30: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_29.ref
# Util2d rech_32: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_31.ref
# Util2d rech_34: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_33.ref
# Util2d rech_36: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_35.ref
# Util2d rech_38: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_37.ref
# Util2d rech_40: locat is None, but model does not support free format and how is internal...resetting how = external
# BaseModel.add_external() warning: replacing existing filename rech_39.ref
# FloPy is using the following  executable to run the model: /Users/ianpg/Documents/ProjectsLocal/SyntheticSWI/bin/modflow_macOS/swt_v4
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: test.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2020/02/02 18:07:03
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    180.00
#
#  Transport Step:    1   Step Size:  1.0000E-03 Total Elapsed Time:  1.00000E-03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    2   Step Size:  0.9990     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7786E-02  [K,I,J]    7   10  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2870E-04  [K,I,J]    7   10   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1395E-06  [K,I,J]    6   10   99
#  Transport Step:    3   Step Size:   4.223     Total Elapsed Time:   5.2229
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3119E-01  [K,I,J]    7   10  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4717E-03  [K,I,J]    7   10   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9639E-05  [K,I,J]    6   10   99
#  Transport Step:    4   Step Size:   6.942     Total Elapsed Time:   12.165
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4746E-01  [K,I,J]    8    3  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1097E-02  [K,I,J]    7   10   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3554E-04  [K,I,J]    6   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1876E-05  [K,I,J]    7   10   99
#  Transport Step:    5   Step Size:   9.041     Total Elapsed Time:   21.207
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5973E-01  [K,I,J]    8    3  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1572E-02  [K,I,J]    7   10   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6478E-04  [K,I,J]    6   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4588E-05  [K,I,J]    7   10   99
#  Transport Step:    6   Step Size:   10.21     Total Elapsed Time:   31.417
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6471E-01  [K,I,J]    8    3  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1693E-02  [K,I,J]    7   10   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7902E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6565E-05  [K,I,J]    7   10   99
#  Transport Step:    7   Step Size:   10.72     Total Elapsed Time:   42.137
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6494E-01  [K,I,J]    8    3  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1585E-02  [K,I,J]    7   10   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7810E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7173E-05  [K,I,J]    7   10   99
#  Transport Step:    8   Step Size:   10.96     Total Elapsed Time:   53.093
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6327E-01  [K,I,J]    8    3  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1415E-02  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7181E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7083E-05  [K,I,J]    7   10   99
#  Transport Step:    9   Step Size:   11.07     Total Elapsed Time:   64.161
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6131E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1399E-02  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6424E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6617E-05  [K,I,J]    7   10   99
#  Transport Step:   10   Step Size:   11.13     Total Elapsed Time:   75.292
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6182E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1356E-02  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5710E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6040E-05  [K,I,J]    7   10   99
#  Transport Step:   11   Step Size:   11.17     Total Elapsed Time:   86.463
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6195E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1302E-02  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5095E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5459E-05  [K,I,J]    7   10   99
#  Transport Step:   12   Step Size:   11.20     Total Elapsed Time:   97.659
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6188E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1244E-02  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4584E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4923E-05  [K,I,J]    7   10   99
#  Transport Step:   13   Step Size:   11.21     Total Elapsed Time:   108.87
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6167E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1186E-02  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4165E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4447E-05  [K,I,J]    7   10   99
#  Transport Step:   14   Step Size:   11.22     Total Elapsed Time:   120.09
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6135E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1177E-02  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3822E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4028E-05  [K,I,J]    7   10   99
#  Transport Step:   15   Step Size:   11.23     Total Elapsed Time:   131.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6094E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1175E-02  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3539E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3669E-05  [K,I,J]    7   10   99
#  Transport Step:   16   Step Size:   11.23     Total Elapsed Time:   142.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6047E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1171E-02  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3305E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3362E-05  [K,I,J]    7   10   99
#  Transport Step:   17   Step Size:   11.23     Total Elapsed Time:   153.78
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5995E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1165E-02  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3108E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3095E-05  [K,I,J]    7   10   99
#  Transport Step:   18   Step Size:   11.23     Total Elapsed Time:   165.01
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5938E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1158E-02  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2940E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2862E-05  [K,I,J]    7   10   99
#  Transport Step:   19   Step Size:   11.22     Total Elapsed Time:   176.23
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5872E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1149E-02  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2792E-04  [K,I,J]    8   10   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2655E-05  [K,I,J]    7   10   99
#  Transport Step:   20   Step Size:   3.768     Total Elapsed Time:   180.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2008E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1366E-03  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1227E-05  [K,I,J]    7    3   99
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   180.00     TO    360.00
#
#  Transport Step:    1   Step Size:   11.22     Total Elapsed Time:   191.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5625E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1076E-02  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2527E-04  [K,I,J]    7    3   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2272E-05  [K,I,J]    7   10   99
#  Transport Step:    2   Step Size:   1.481     Total Elapsed Time:   192.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7570E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1989E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7190E-07  [K,I,J]    7    3   99
#  Transport Step:    3   Step Size:   1.648     Total Elapsed Time:   194.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8356E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2429E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9714E-07  [K,I,J]    7    3   99
#  Transport Step:    4   Step Size:   1.841     Total Elapsed Time:   196.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9241E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1323E-06  [K,I,J]    7    3   99
#  Transport Step:    5   Step Size:   2.042     Total Elapsed Time:   198.23
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1013E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3588E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1756E-06  [K,I,J]    7    3   99
#  Transport Step:    6   Step Size:   2.250     Total Elapsed Time:   200.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1099E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4242E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2275E-06  [K,I,J]    7    3   99
#  Transport Step:    7   Step Size:   2.470     Total Elapsed Time:   202.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1185E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4948E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2900E-06  [K,I,J]    7    3   99
#  Transport Step:    8   Step Size:   2.706     Total Elapsed Time:   205.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1269E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5702E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3651E-06  [K,I,J]    7    3   99
#  Transport Step:    9   Step Size:   2.960     Total Elapsed Time:   208.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1350E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6492E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4541E-06  [K,I,J]    7    3   99
#  Transport Step:   10   Step Size:   3.236     Total Elapsed Time:   211.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1427E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7297E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5593E-06  [K,I,J]    7    3   99
#  Transport Step:   11   Step Size:   3.537     Total Elapsed Time:   215.39
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1497E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8089E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6817E-06  [K,I,J]    7    3   99
#  Transport Step:   12   Step Size:   3.865     Total Elapsed Time:   219.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1557E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8827E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8224E-06  [K,I,J]    7    3   99
#  Transport Step:   13   Step Size:   4.223     Total Elapsed Time:   223.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1603E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9462E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9809E-06  [K,I,J]    7    3   99
#  Transport Step:   14   Step Size:   4.616     Total Elapsed Time:   228.09
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1633E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9935E-04  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1155E-05  [K,I,J]    7    3   99
#  Transport Step:   15   Step Size:   5.046     Total Elapsed Time:   233.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1641E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1018E-03  [K,I,J]   10   17   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1339E-05  [K,I,J]    7    3   99
#  Transport Step:   16   Step Size:   5.518     Total Elapsed Time:   238.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1624E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1094E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1567E-05  [K,I,J]    6   10   99
#  Transport Step:   17   Step Size:   6.036     Total Elapsed Time:   244.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1576E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1166E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1848E-05  [K,I,J]    6   10   99
#  Transport Step:   18   Step Size:   6.606     Total Elapsed Time:   251.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1930E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1229E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2285E-05  [K,I,J]   25   14   64
#  Transport Step:   19   Step Size:   7.233     Total Elapsed Time:   258.53
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2600E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2025E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3263E-05  [K,I,J]   24   14   63
#  Transport Step:   20   Step Size:   7.902     Total Elapsed Time:   266.43
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3372E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3384E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4811E-05  [K,I,J]   26   15   99
#  Transport Step:   21   Step Size:   8.636     Total Elapsed Time:   275.07
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4260E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5357E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7492E-05  [K,I,J]   26   15   99
#  Transport Step:   22   Step Size:   9.445     Total Elapsed Time:   284.51
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5272E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8135E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1346E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3880E-06  [K,I,J]   24   14   64
#  Transport Step:   23   Step Size:   10.34     Total Elapsed Time:   294.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6421E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1196E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2380E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6126E-06  [K,I,J]   24   14   64
#  Transport Step:   24   Step Size:   11.33     Total Elapsed Time:   306.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7725E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1713E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4044E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1004E-05  [K,I,J]   26   15   97
#  Transport Step:   25   Step Size:   12.44     Total Elapsed Time:   318.63
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9203E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2406E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6663E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1939E-05  [K,I,J]   26   15   97
#  Transport Step:   26   Step Size:   13.68     Total Elapsed Time:   332.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1088      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3325E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1072E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3620E-05  [K,I,J]   26   15   97
#  Transport Step:   27   Step Size:   15.08     Total Elapsed Time:   347.39
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1281      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4541E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1693E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6591E-05  [K,I,J]   26   15   97
#  Transport Step:   28   Step Size:   12.61     Total Elapsed Time:   360.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1120      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3509E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1157E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3969E-05  [K,I,J]   26   15   97
#
#  STRESS PERIOD NO.    3
#
#   STRESS PERIOD    3 TIME STEP    1 FROM TIME =   360.00     TO    540.00
#
#  Transport Step:    1   Step Size:   16.66     Total Elapsed Time:   376.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1470      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5898E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2475E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1117E-04  [K,I,J]   21    8   98
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7844E-06  [K,I,J]   22    8   98
#  Transport Step:    2   Step Size:   3.011     Total Elapsed Time:   379.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2638E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2059E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1705E-05  [K,I,J]   26   15   98
#  Transport Step:    3   Step Size:  0.3325     Total Elapsed Time:   380.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2909E-02  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2545E-05  [K,I,J]   26   15   99
#  Transport Step:    4   Step Size:   4.411     Total Elapsed Time:   384.41
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3816E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4274E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5067E-05  [K,I,J]   26   15   98
#  Transport Step:    5   Step Size:   6.007     Total Elapsed Time:   390.42
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5050E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7421E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1152E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1967E-06  [K,I,J]   21    8   98
#  Transport Step:    6   Step Size:   8.020     Total Elapsed Time:   398.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6357E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1165E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2252E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4815E-06  [K,I,J]   21    8   98
#  Transport Step:    7   Step Size:   10.47     Total Elapsed Time:   408.91
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7481E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1602E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3608E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9019E-06  [K,I,J]   21    8   98
#  Transport Step:    8   Step Size:   13.58     Total Elapsed Time:   422.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8249E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1937E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4780E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1308E-05  [K,I,J]   21    8   98
#  Transport Step:    9   Step Size:   15.42     Total Elapsed Time:   437.91
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7625E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1661E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3806E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9577E-06  [K,I,J]   21    8   98
#  Transport Step:   10   Step Size:   15.86     Total Elapsed Time:   453.77
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6243E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1125E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2137E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7969E-06  [K,I,J]    7   10   99
#  Transport Step:   11   Step Size:   15.56     Total Elapsed Time:   469.33
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4834E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6824E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1024E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8777E-06  [K,I,J]    7   10   99
#  Transport Step:   12   Step Size:   15.27     Total Elapsed Time:   484.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3708E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4070E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1133E-04  [K,I,J]    7    2   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8957E-06  [K,I,J]    7   10   99
#  Transport Step:   13   Step Size:   14.98     Total Elapsed Time:   499.58
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2809E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4155E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1276E-04  [K,I,J]    7    2   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9220E-06  [K,I,J]    6   10   97
#  Transport Step:   14   Step Size:   14.71     Total Elapsed Time:   514.28
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2454E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4552E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1405E-04  [K,I,J]    7    2   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9811E-06  [K,I,J]    6   10   97
#  Transport Step:   15   Step Size:   14.45     Total Elapsed Time:   528.73
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2752E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4887E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1515E-04  [K,I,J]    7    2   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1023E-05  [K,I,J]    6   10   97
#  Transport Step:   16   Step Size:   11.27     Total Elapsed Time:   540.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2331E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3238E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8121E-05  [K,I,J]    7    2   99
#
#  STRESS PERIOD NO.    4
#
#   STRESS PERIOD    4 TIME STEP    1 FROM TIME =   540.00     TO    720.00
#
#  Transport Step:    1   Step Size:   14.03     Total Elapsed Time:   554.03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2856E-01  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4781E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1465E-04  [K,I,J]    7    2   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9352E-06  [K,I,J]    6   10   97
#  Transport Step:    2   Step Size:   1.633     Total Elapsed Time:   555.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3306E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6863E-05  [K,I,J]    8    2   99
#  Transport Step:    3   Step Size:   1.832     Total Elapsed Time:   557.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3685E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8559E-05  [K,I,J]    8    2   99
#  Transport Step:    4   Step Size:   2.065     Total Elapsed Time:   559.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4112E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1074E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5227E-07  [K,I,J]    7    2   99
#  Transport Step:    5   Step Size:   2.312     Total Elapsed Time:   561.87
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4532E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1323E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7172E-07  [K,I,J]    7    2   99
#  Transport Step:    6   Step Size:   2.574     Total Elapsed Time:   564.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4936E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1601E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9632E-07  [K,I,J]    7    2   99
#  Transport Step:    7   Step Size:   2.859     Total Elapsed Time:   567.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5315E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1919E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1270E-06  [K,I,J]    7    2   99
#  Transport Step:    8   Step Size:   3.171     Total Elapsed Time:   570.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5649E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2273E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1654E-06  [K,I,J]    7    2   99
#  Transport Step:    9   Step Size:   3.516     Total Elapsed Time:   573.99
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5911E-02  [K,I,J]   10   17  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2667E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2123E-06  [K,I,J]    7    2   99
#  Transport Step:   10   Step Size:   3.900     Total Elapsed Time:   577.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7223E-02  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3096E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2685E-06  [K,I,J]    7    2   99
#  Transport Step:   11   Step Size:   4.329     Total Elapsed Time:   582.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9554E-02  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3558E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3342E-06  [K,I,J]    7    2   99
#  Transport Step:   12   Step Size:   4.809     Total Elapsed Time:   587.03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1266E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4833E-04  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4097E-06  [K,I,J]    7    2   99
#  Transport Step:   13   Step Size:   5.348     Total Elapsed Time:   592.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1673E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8411E-04  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7961E-06  [K,I,J]   26   15   99
#  Transport Step:   14   Step Size:   5.954     Total Elapsed Time:   598.33
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2193E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1440E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1444E-05  [K,I,J]   26   15   99
#  Transport Step:   15   Step Size:   6.636     Total Elapsed Time:   604.97
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2845E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2410E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2474E-05  [K,I,J]   26   15   99
#  Transport Step:   16   Step Size:   7.404     Total Elapsed Time:   612.37
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3647E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3936E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4567E-05  [K,I,J]   26   15   98
#  Transport Step:   17   Step Size:   8.271     Total Elapsed Time:   620.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4619E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6263E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9099E-05  [K,I,J]   26   15   98
#  Transport Step:   18   Step Size:   9.229     Total Elapsed Time:   629.87
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5764E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9666E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1729E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3262E-06  [K,I,J]   26   15   97
#  Transport Step:   19   Step Size:   10.30     Total Elapsed Time:   640.17
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7100E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1452E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3154E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7212E-06  [K,I,J]   26   15   97
#  Transport Step:   20   Step Size:   11.50     Total Elapsed Time:   651.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8653E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2133E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5561E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1519E-05  [K,I,J]   26   15   97
#  Transport Step:   21   Step Size:   12.86     Total Elapsed Time:   664.53
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1045      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3072E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9518E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3076E-05  [K,I,J]   26   15   97
#  Transport Step:   22   Step Size:   14.41     Total Elapsed Time:   678.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1253      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4353E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1588E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6153E-05  [K,I,J]   21    8   98
#  Transport Step:   23   Step Size:   16.18     Total Elapsed Time:   695.12
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1493      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6085E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2596E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1198E-04  [K,I,J]   21    8   98
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8257E-06  [K,I,J]   22    8   98
#  Transport Step:   24   Step Size:   18.20     Total Elapsed Time:   713.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1773      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8418E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4171E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2268E-04  [K,I,J]   21    8   98
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1855E-05  [K,I,J]   22    8   98
#  Transport Step:   25   Step Size:   6.680     Total Elapsed Time:   720.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6600E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1256E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2524E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5626E-06  [K,I,J]   21    8   98
#
#  STRESS PERIOD NO.    5
#
#   STRESS PERIOD    5 TIME STEP    1 FROM TIME =   720.00     TO    900.00
#
#  Transport Step:    1   Step Size:   19.34     Total Elapsed Time:   739.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1862      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9225E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4760E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2755E-04  [K,I,J]   21    8   98
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2396E-05  [K,I,J]   22    8   98
#  Transport Step:    2   Step Size:   3.262     Total Elapsed Time:   742.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3102E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2839E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2752E-05  [K,I,J]   26   15   98
#  Transport Step:    3   Step Size:   4.586     Total Elapsed Time:   747.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4289E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5384E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7147E-05  [K,I,J]   26   15   98
#  Transport Step:    4   Step Size:   6.265     Total Elapsed Time:   753.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5662E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9294E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1610E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3196E-06  [K,I,J]   21    8   98
#  Transport Step:    5   Step Size:   5.546     Total Elapsed Time:   759.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4815E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6760E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1002E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1712E-06  [K,I,J]   21    8   98
#  Transport Step:    6   Step Size:   10.04     Total Elapsed Time:   769.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7941E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1800E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4290E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1180E-05  [K,I,J]   21    8   98
#  Transport Step:    7   Step Size:   12.84     Total Elapsed Time:   781.88
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8796E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2195E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5755E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1746E-05  [K,I,J]   21    8   98
#  Transport Step:    8   Step Size:   14.49     Total Elapsed Time:   796.37
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8286E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1953E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4841E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1394E-05  [K,I,J]   21    8   98
#  Transport Step:    9   Step Size:   16.15     Total Elapsed Time:   812.51
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7457E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1591E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3570E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9245E-06  [K,I,J]   21    8   98
#  Transport Step:   10   Step Size:   16.93     Total Elapsed Time:   829.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6187E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1105E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2081E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7931E-06  [K,I,J]    6   10   97
#  Transport Step:   11   Step Size:   16.43     Total Elapsed Time:   845.87
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4732E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6543E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1172E-04  [K,I,J]    6   10   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9181E-06  [K,I,J]    6   10   97
#  Transport Step:   12   Step Size:   15.98     Total Elapsed Time:   861.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3600E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4389E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1250E-04  [K,I,J]    6   10   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1020E-05  [K,I,J]    6   10   97
#  Transport Step:   13   Step Size:   15.57     Total Elapsed Time:   877.42
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2742E-01  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4920E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1376E-04  [K,I,J]    7    2   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1110E-05  [K,I,J]    6   10   97
#  Transport Step:   14   Step Size:   15.19     Total Elapsed Time:   892.61
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2848E-01  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5389E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1519E-04  [K,I,J]    7    2   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1181E-05  [K,I,J]    6   10   97
#  Transport Step:   15   Step Size:   7.390     Total Elapsed Time:   900.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1422E-01  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1405E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2043E-05  [K,I,J]    7    2   99
#
#  STRESS PERIOD NO.    6
#
#   STRESS PERIOD    6 TIME STEP    1 FROM TIME =   900.00     TO    1080.0
#
#  Transport Step:    1   Step Size:   14.70     Total Elapsed Time:   914.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2764E-01  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5196E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1450E-04  [K,I,J]    7    2   99
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1071E-05  [K,I,J]    6   10   97
#  Transport Step:    2   Step Size:   1.665     Total Elapsed Time:   916.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3116E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7047E-05  [K,I,J]    8    2   99
#  Transport Step:    3   Step Size:   1.871     Total Elapsed Time:   918.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3482E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8806E-05  [K,I,J]    8    2   99
#  Transport Step:    4   Step Size:   2.112     Total Elapsed Time:   920.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3903E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1108E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4731E-07  [K,I,J]    7    2   99
#  Transport Step:    5   Step Size:   2.367     Total Elapsed Time:   922.71
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4332E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1367E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6509E-07  [K,I,J]    7    2   99
#  Transport Step:    6   Step Size:   2.641     Total Elapsed Time:   925.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4770E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1658E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8783E-07  [K,I,J]    7    2   99
# ...
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1345E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2315E-06  [K,I,J]   26   15   97
#  Transport Step:   18   Step Size:   9.896     Total Elapsed Time:   1354.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6579E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1251E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2519E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5295E-06  [K,I,J]   26   15   97
#  Transport Step:   19   Step Size:   11.09     Total Elapsed Time:   1365.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8080E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1867E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4557E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1158E-05  [K,I,J]   26   15   97
#  Transport Step:   20   Step Size:   12.45     Total Elapsed Time:   1378.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9830E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2730E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7988E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2467E-05  [K,I,J]   21    8   98
#  Transport Step:   21   Step Size:   13.99     Total Elapsed Time:   1392.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1186      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3921E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1362E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5081E-05  [K,I,J]   21    8   98
#  Transport Step:   22   Step Size:   15.76     Total Elapsed Time:   1407.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1422      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5549E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2269E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1009E-04  [K,I,J]   21    8   98
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6576E-06  [K,I,J]   22    8   98
#  Transport Step:   23   Step Size:   17.79     Total Elapsed Time:   1425.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1697      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7758E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3707E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1949E-04  [K,I,J]   21    8   98
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1497E-05  [K,I,J]   22    8   98
#  Transport Step:   24   Step Size:   14.34     Total Elapsed Time:   1440.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1418      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5511E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2247E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1015E-04  [K,I,J]   21    8   98
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6686E-06  [K,I,J]   22    8   98
#
#  STRESS PERIOD NO.    9
#
#   STRESS PERIOD    9 TIME STEP    1 FROM TIME =   1440.0     TO    1620.0
#
#  Transport Step:    1   Step Size:   19.99     Total Elapsed Time:   1460.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1912      [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9702E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5128E-03  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3056E-04  [K,I,J]   21    8   98
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2734E-05  [K,I,J]   22    8   98
#  Transport Step:    2   Step Size:   3.323     Total Elapsed Time:   1463.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3137E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2904E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2848E-05  [K,I,J]   26   15   98
#  Transport Step:    3   Step Size:   4.675     Total Elapsed Time:   1468.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4334E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5497E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7375E-05  [K,I,J]   26   15   98
#  Transport Step:    4   Step Size:   6.384     Total Elapsed Time:   1474.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5704E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9435E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1647E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3319E-06  [K,I,J]   21    8   98
#  Transport Step:    5   Step Size:   8.467     Total Elapsed Time:   1482.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7069E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1435E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3069E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7607E-06  [K,I,J]   21    8   98
#  Transport Step:    6   Step Size:   10.92     Total Elapsed Time:   1493.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8160E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1898E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4643E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1322E-05  [K,I,J]   21    8   98
#  Transport Step:    7   Step Size:   13.31     Total Elapsed Time:   1507.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8490E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2049E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5200E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1543E-05  [K,I,J]   21    8   98
#  Transport Step:    8   Step Size:   9.922     Total Elapsed Time:   1517.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5550E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8931E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1515E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3028E-06  [K,I,J]   21    8   98
#  Transport Step:    9   Step Size:   16.09     Total Elapsed Time:   1533.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7238E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1502E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3275E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8417E-06  [K,I,J]   21    8   98
#  Transport Step:   10   Step Size:   17.22     Total Elapsed Time:   1550.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6063E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1064E-02  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1967E-04  [K,I,J]   26   15   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1171E-05  [K,I,J]    6   10   97
#  Transport Step:   11   Step Size:   16.68     Total Elapsed Time:   1567.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4565E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6120E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1484E-04  [K,I,J]    6   10   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1335E-05  [K,I,J]    6   10   97
#  Transport Step:   12   Step Size:   16.19     Total Elapsed Time:   1583.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3407E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4796E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1571E-04  [K,I,J]    6   10   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1487E-05  [K,I,J]    6   10   97
#  Transport Step:   13   Step Size:   15.74     Total Elapsed Time:   1598.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3174E-01  [K,I,J]    8    3  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5486E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1638E-04  [K,I,J]    6   10   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1625E-05  [K,I,J]    6   10   97
#  Transport Step:   14   Step Size:   15.35     Total Elapsed Time:   1614.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3288E-01  [K,I,J]    8    3  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6064E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1704E-04  [K,I,J]    6   10   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1726E-05  [K,I,J]    6   10   97
#  Transport Step:   15   Step Size:   5.726     Total Elapsed Time:   1620.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1252E-01  [K,I,J]    8    3  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9275E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1135E-05  [K,I,J]    6   10   98
#
#  STRESS PERIOD NO.   10
#
#   STRESS PERIOD   10 TIME STEP    1 FROM TIME =   1620.0     TO    1800.0
#
#  Transport Step:    1   Step Size:   14.86     Total Elapsed Time:   1634.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3177E-01  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5809E-03  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1560E-04  [K,I,J]    6   10   98
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1555E-05  [K,I,J]    6   10   97
#  Transport Step:    2   Step Size:   1.672     Total Elapsed Time:   1636.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3557E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7765E-05  [K,I,J]    8    2   99
#  Transport Step:    3   Step Size:   1.879     Total Elapsed Time:   1638.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3977E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9713E-05  [K,I,J]    8    2   99
#  Transport Step:    4   Step Size:   2.123     Total Elapsed Time:   1640.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4458E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1222E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5845E-07  [K,I,J]    6   10   98
#  Transport Step:    5   Step Size:   2.380     Total Elapsed Time:   1642.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4948E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1507E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8046E-07  [K,I,J]    6   10   98
#  Transport Step:    6   Step Size:   2.656     Total Elapsed Time:   1645.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5446E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1829E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1084E-06  [K,I,J]    6   10   98
#  Transport Step:    7   Step Size:   2.957     Total Elapsed Time:   1648.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5954E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2190E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1439E-06  [K,I,J]    6   10   98
#  Transport Step:    8   Step Size:   3.288     Total Elapsed Time:   1651.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6467E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2591E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1885E-06  [K,I,J]    6   10   98
#  Transport Step:    9   Step Size:   3.656     Total Elapsed Time:   1655.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6979E-02  [K,I,J]    8    1  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3026E-04  [K,I,J]    8    2   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2436E-06  [K,I,J]    6   10   98
#  Transport Step:   10   Step Size:   4.067     Total Elapsed Time:   1659.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8624E-02  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4145E-04  [K,I,J]   25   10   60
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3108E-06  [K,I,J]    6   10   98
#  Transport Step:   11   Step Size:   4.528     Total Elapsed Time:   1664.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1127E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5704E-04  [K,I,J]   25   10   60
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4402E-06  [K,I,J]   24   10   60
#  Transport Step:   12   Step Size:   5.048     Total Elapsed Time:   1669.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1479E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7800E-04  [K,I,J]   25   10   60
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7756E-06  [K,I,J]   25   10   59
#  Transport Step:   13   Step Size:   5.634     Total Elapsed Time:   1674.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1937E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1126E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1364E-05  [K,I,J]   25   10   59
#  Transport Step:   14   Step Size:   6.296     Total Elapsed Time:   1681.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2522E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1899E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2301E-05  [K,I,J]   25   10   59
#  Transport Step:   15   Step Size:   7.045     Total Elapsed Time:   1688.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3254E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3141E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3721E-05  [K,I,J]   25   10   59
#  Transport Step:   16   Step Size:   7.895     Total Elapsed Time:   1696.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4154E-01  [K,I,J]   26   15  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5082E-03  [K,I,J]   26   15   99
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6646E-05  [K,I,J]   26   15   98
#  Transport Step:   17   Step Size:   8.858     Total Elapsed Time:   1704.8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-dcfd4790bba8> in <module>
#       7 m, varlist = update_run_model(varlist,it,runyn=runyn,
#       8                              start_basecase=True,silent=False,
# ----> 9                              pooling=pooling,f_basecase=fpath_basecase)
#      10
#      11 # varlist_arr = make_varlist_array(varlist)
#
# <ipython-input-22-e1d60c509134> in update_run_model(varlist, it, m, homogenous, runyn, plotyn, silent, start_basecase, f_basecase, pooling, output, results)
#     523     # Run model
#     524     if runyn:
# --> 525         v = m.run_model(silent=silent, report=True)
#     526         for idx in range(-3, 0):  # Report
#     527             print(v[1][idx])
#
# ~/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy/mbase.py in run_model(self, silent, pause, report, normal_msg)
#     968         return run_model(self.exe_name, self.namefile, model_ws=self.model_ws,
#     969                          silent=silent, pause=pause, report=report,
# --> 970                          normal_msg=normal_msg)
#     971
#     972     def load_results(self):
#
# ~/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy/mbase.py in run_model(exe_name, namefile, model_ws, silent, pause, report, normal_msg, use_async, cargs)
#    1412     if not use_async:
#    1413         while True:
# -> 1414             line = proc.stdout.readline()
#    1415             c = line.decode('utf-8')
#    1416             if c != '':
#
# KeyboardInterrupt:

# %%
m.verbose=True

# %%
m.write_input()
# Out:
# Writing packages:
#    Package:  DIS
#    Package:  BAS6
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-65afee0ed742> in <module>
# ----> 1 m.write_input()
#
# ~/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy/mbase.py in write_input(self, SelPackList, check)
#    1012                 # or default for package level check would have to be False
#    1013                 try:
# -> 1014                     p.write_file(check=False)
#    1015                 except TypeError:
#    1016                     p.write_file()
#
# ~/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy/modflow/mfbas.py in write_file(self, check)
#     210             self.check(f='{}.chk'.format(self.name[0]), verbose=self.parent.verbose, level=1)
#     211         # Open file for writing
# --> 212         f_bas = open(self.fn_path, 'w')
#     213         # First line: heading
#     214         #f_bas.write('%s\n' % self.heading)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../work/heterog_1000/MC_expt_20200202_1427/tmp0/../work/homog/homog.bas'

# %%
m.write_input??
# Out:
# Signature: m.write_input(SelPackList=False, check=False)
# Source:
#     def write_input(self, SelPackList=False, check=False):
#         """
#         Write the input.
#
#         Parameters
#         ----------
#         SelPackList : False or list of packages
#
#         """
#         if check:
#             # run check prior to writing input
#             self.check(f='{}.chk'.format(self.name), verbose=self.verbose,
#                        level=1)
#
#         # reset the model to free_format if parameter substitution was
#         # performed on a model load
#         if self.parameter_load and not self.free_format_input:
#             if self.verbose:
#                 print('\nReseting free_format_input to True to ' +
#                       'preserve the precision of the parameter data.')
#             self.free_format_input = True
#
#         if self.verbose:
#             print('\nWriting packages:')
#
#         if SelPackList == False:
#             for p in self.packagelist:
#                 if self.verbose:
#                     print('   Package: ', p.name[0])
#                 # prevent individual package checks from running after
#                 # model-level package check above
#                 # otherwise checks are run twice
#                 # or the model level check procedure would have to be split up
#                 # or each package would need a check arguemnt,
#                 # or default for package level check would have to be False
#                 try:
#                     p.write_file(check=False)
#                 except TypeError:
#                     p.write_file()
#         else:
#             for pon in SelPackList:
#                 for i, p in enumerate(self.packagelist):
#                     if pon in p.name:
#                         if self.verbose:
#                             print('   Package: ', p.name[0])
#                         try:
#                             p.write_file(check=False)
#                         except TypeError:
#                             p.write_file()
#                             break
#         if self.verbose:
#             print(' ')
#         # write name file
#         self.write_name_file()
#         # os.chdir(org_dir)
#         return
# File:      ~/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy/mbase.py
# Type:      method

# %%
bas.fn_path
# Out:
# '../work/heterog_1000/MC_expt_20200202_1427/tmp0/../work/homog/homog.bas'

# %%
bas = flopy.modflow.ModflowBas(m, m.bas6.ibound.array, strt=m.bas6.strt)
# Out:
# WARNING: unit 13 of package BAS6 already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfbas.ModflowBas'> <class 'flopy.modflow.mfbas.ModflowBas'>
# replacing existing Package...

# %%
m.name
# Out:
# '../work/homog/homog'
